# %%
# Test 1: Using the simple inspect() function
from injex import inspect

result = inspect("Explain how AI systems work")
print("Result:", result)
print(f"Decision: {result['decision']}, Score: {result['score']:.4f}")
# Out:
# Result: {'text': 'Explain how AI systems work', 'score': 0.7014394932593288, 'decision': 'ALLOW'}
# Decision: ALLOW, Score: 0.7014
